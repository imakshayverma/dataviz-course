# %%
import pandas as pd
% matplotlib inline

# %%
df = pd.read_csv("../datasets/states.csv")

# %%
df.shape
# Out:
# (29, 42)

# %%
df.columns
# Out:
# Index([u'State', u'Per Capita NSDP at 2004-05 prices (Rs.)',
#        u'Growth in Per Capita NSDP at 2004-05 prices (%)',
#        u'Growth rate in GSDP-Total', u'Growth rate in GSDP-Agriculture',
#        u'Growth rate in GSDP-Industry', u'Growth rate in GSDP-services',
#        u'Area (Sq. Km.)', u'Population (crore)',
#        u'Population Density (Per Sq. Km.)',
#        u'Decadal Growth Rate of Population (2001-2011) (%)',
#        u'Sex Ratio (Females/ 1000 Males)',
#        u'Sex Ratio (0-6 years) (Female children/ 1000 male children)',
#        u'Total Literacy Rate (%)', u'Male (%)', u'Female (%)',
#        u'Gender Gap in Literacy (%)',
#        u'Infant Mortality Rate (IMR) (per 1000 live births)',
#        u'Maternal Mortality Rate (MMR) (per 100000 live births)',
#        u'Total Fertility Rate (TFR) (Birth/ woman)',
#        u'Neo Natal Mortality Rate (NMR) (per 1000 live births)',
#        u'Under 5 Mortality Rate (U-5MR) (per 1000 live births)',
# ...

# %%
df.head(3)
# Out:
#             State  Per Capita NSDP at 2004-05 prices (Rs.)  \
# 0       All India                                    38856
# 1  Andhra Pradesh                                    44526
# 2           Bihar                                    14362
#
#    Growth in Per Capita NSDP at 2004-05 prices (%)  Growth rate in GSDP-Total  \
# 0                                             2.12                       4.70
# 1                                             4.55                       5.09
# 2                                             9.23                      10.74
#
#    Growth rate in GSDP-Agriculture  Growth rate in GSDP-Industry  \
# 0                             4.70                          0.40
# 1                             4.78                         -0.46
# 2                             3.00                          0.95
#
#    Growth rate in GSDP-services  Area (Sq. Km.)  Population (crore)  \
# 0                          6.80         3287240              121.02
# ...

# %%
df.describe()
# Out:
#        Per Capita NSDP at 2004-05 prices (Rs.)  \
# count                                29.000000
# mean                              45245.931034
# std                               26329.633967
# min                               14362.000000
# 25%                               27421.000000
# 50%                               39347.000000
# 75%                               54462.000000
# max                              132121.000000
#
#        Growth in Per Capita NSDP at 2004-05 prices (%)  \
# count                                        29.000000
# mean                                          4.191034
# std                                           2.570348
# min                                          -1.510000
# 25%                                           2.860000
# 50%                                           3.820000
# 75%                                           5.360000
# max                                           9.230000
#
# ...

# %%
df[1:]
# Out:
#                 State  Per Capita NSDP at 2004-05 prices (Rs.)  \
# 1      Andhra Pradesh                                    44526
# 2               Bihar                                    14362
# 3   Arunachal Pradesh                                    35845
# 4      Madhya Pradesh                                    25463
# 5        Chhattisgarh                                    27421
# 6       Uttar Pradesh                                    18595
# 7         Maharashtra                                    64218
# 8               Assam                                    23448
# 9         West Bengal                                    33889
# 10              Delhi                                   118960
# 11             Kerala                                    56115
# 12              J & K                                    29754
# 13            Gujarat                                    61220
# 14           Nagaland                                    48111
# ...

# %%
df[1:].describe()
# Out:
#        Per Capita NSDP at 2004-05 prices (Rs.)  \
# count                                28.000000
# mean                              45474.142857
# std                               26783.563243
# min                               14362.000000
# 25%                               27318.250000
# 50%                               40831.000000
# 75%                               54875.250000
# max                              132121.000000
#
#        Growth in Per Capita NSDP at 2004-05 prices (%)  \
# count                                        28.000000
# mean                                          4.265000
# std                                           2.585894
# min                                          -1.510000
# 25%                                           3.107500
# 50%                                           3.870000
# 75%                                           5.662500
# max                                           9.230000
#
# ...

# %%
df[["State", "Safe Drinking Water (Tap/Handpump/Tubewell) (%age)"]]
# Out:
#                 State  Safe Drinking Water (Tap/Handpump/Tubewell) (%age)
# 0           All India                                               85.5
# 1      Andhra Pradesh                                               90.5
# 2               Bihar                                               94.0
# 3   Arunachal Pradesh                                               78.6
# 4      Madhya Pradesh                                               78.0
# 5        Chhattisgarh                                               86.3
# 6       Uttar Pradesh                                               95.1
# 7         Maharashtra                                               83.4
# 8               Assam                                               69.9
# 9         West Bengal                                               92.2
# 10              Delhi                                               95.0
# 11             Kerala                                               33.5
# ...

# %%
df["Safe Drinking Water (Tap/Handpump/Tubewell) (%age)"] > 78
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26     True
# 27    False
# 28     True
# Name: Safe Drinking Water (Tap/Handpump/Tubewell) (%age), dtype: bool

# %%
df[["State", "Safe Drinking Water (Tap/Handpump/Tubewell) (%age)"]][df["Safe Drinking Water (Tap/Handpump/Tubewell) (%age)"]<78]
# Out:
#         State  Safe Drinking Water (Tap/Handpump/Tubewell) (%age)
# 8       Assam                                               69.9
# 11     Kerala                                               33.5
# 12      J & K                                               76.8
# 14   Nagaland                                               53.8
# 16    Tripura                                               67.5
# 17  Jharkhand                                               60.1
# 22    Mizoram                                               60.4
# 23    Manipur                                               45.4
# 25  Meghalaya                                               44.7
# 27     Odisha                                               75.3

# %%
new_df  = df[["State", "Forest Cover (% of geographical area)"]]
new_df
# Out:
#                 State  Forest Cover (% of geographical area)
# 0           All India                                   21.2
# 1      Andhra Pradesh                                   16.8
# 2               Bihar                                    7.7
# 3   Arunachal Pradesh                                   80.4
# 4      Madhya Pradesh                                   25.2
# 5        Chhattisgarh                                   41.1
# 6       Uttar Pradesh                                    6.0
# 7         Maharashtra                                   16.5
# 8               Assam                                   35.3
# 9         West Bengal                                   18.9
# 10              Delhi                                   12.1
# 11             Kerala                                   46.1
# 12              J & K                                   10.1
# 13            Gujarat                                    7.5
# ...

# %%
new_df = new_df[df["Forest Cover (% of geographical area)"] < 50].sort_values(by="Forest Cover (% of geographical area)", ascending=False)

# %%
new_df
# Out:
#                 State  Forest Cover (% of geographical area)
# 22            Mizoram                                   90.4
# 3   Arunachal Pradesh                                   80.4
# 14           Nagaland                                   78.7
# 25          Meghalaya                                   77.1
# 23            Manipur                                   76.1
# 16            Tripura                                   75.0
# 24                Goa                                   59.9

# %%
new_df.plot(x="State", kind="barh")

# %%
new_df =  df[["State", "Forest Cover (% of geographical area)"]][df["Forest Cover (% of geographical area)"] < 50].sort_values(by="Forest Cover (% of geographical area)").head(5)

# %%
new_df

# %%
new_df.plot()

# %%
new_df.plot(x = "State", kind="bar")

# %%
new_df.plot(x = "State", kind="barh")

# %%
new_df.plot(x = "State", kind="barh", color="green")

# %%
new_df.to_csv("myanalysis.csv")
